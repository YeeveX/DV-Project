# %%
import pandas as pd
import numpy as np
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\aleac\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "c:\Users\aleac\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\aleac\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 701, in start
#     self.io_loop.start()
# ...

# %%
data = pd.read_excel("../apac_aggregated.xlsx")
data.head()
# Out:
#         WEEK                     REGION      COUNTRY      ADMIN1 EVENT_TYPE  \
# 0 2016-12-31  Caucasus and Central Asia  Afghanistan  Badakhshan    Battles
# 1 2017-01-07  Caucasus and Central Asia  Afghanistan  Badakhshan    Battles
# 2 2017-01-21  Caucasus and Central Asia  Afghanistan  Badakhshan    Battles
# 3 2017-02-04  Caucasus and Central Asia  Afghanistan  Badakhshan    Battles
# 4 2017-02-11  Caucasus and Central Asia  Afghanistan  Badakhshan    Battles
#
#   SUB_EVENT_TYPE  EVENTS  FATALITIES  POPULATION_EXPOSURE       DISORDER_TYPE  \
# 0    Armed clash       6          15             113469.0  Political violence
# 1    Armed clash       5          28             155849.0  Political violence
# 2    Armed clash       1           4              38453.0  Political violence
# 3    Armed clash       1           4               1308.0  Political violence
# 4    Armed clash       4          41             143199.0  Political violence
#
# ...

# %%
my_data = data[data['COUNTRY'] == 'Myanmar']

my_data['YEAR'] = my_data['WEEK'].dt.year
my_data['MONTH'] = my_data['WEEK'].dt.month
my_data['DAY'] = my_data['WEEK'].dt.day

after_coup = my_data[(my_data['YEAR'] > 2021) | ((my_data['YEAR'] == 2021) & (my_data['MONTH'] >= 2))]
after_coup.head()
# Out:
# C:\Users\aleac\AppData\Local\Temp\ipykernel_15852\3449467705.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   my_data['YEAR'] = my_data['WEEK'].dt.year
# C:\Users\aleac\AppData\Local\Temp\ipykernel_15852\3449467705.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   my_data['MONTH'] = my_data['WEEK'].dt.month
# C:\Users\aleac\AppData\Local\Temp\ipykernel_15852\3449467705.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
political = after_coup[after_coup['DISORDER_TYPE'] == 'Political violence']

total_events = political.sum(numeric_only=True)['EVENTS']
deadly_events = political[political['FATALITIES'] > 0].sum(numeric_only=True)['EVENTS']

# exposure = political.sum(numeric_only=True)['POPULATION_EXPOSURE']
# total_deaths = political.sum(numeric_only=True)['FATALITIES']

print(total_events, deadly_events)
# Out:
# 54937.0 42390.0
#                    SUB_EVENT_TYPE  EVENTS  FATALITIES  POPULATION_EXPOSURE  \
# 0  Abduction/forced disappearance    2515           0           59085920.0
# 1                Air/drone strike    8533        7105          112311303.0
# 2                     Armed clash   20824       58021          352085970.0
# 3                          Attack    7543        8944          284582480.0
# 4                 Chemical weapon       2           0              30064.0
#
#         ID  CENTROID_LATITUDE  CENTROID_LONGITUDE     YEAR  MONTH    DAY
# 0  2497913         24928.2623         117179.7134  2462678   8531  18708
# 1  3610026         35967.4580         169663.9597  3561903  11751  27618
# 2  6574242         64308.0242         309325.7518  6484178  21489  50009
# 3  5078336         49217.4032         238658.4164  5006588  16359  38305
# 4     4107            38.1756            195.3175     4046      7     11
